# %%
import pandas as pd

# %%
df1=pd.read_csv("D:/M.Sc. Thesis/Data/Diagnostics.csv")

# %%
df1
# Out:
#                          FileName Rhythm       Beat  PatientAge  Gender  \
# 0      MUSE_20180113_171327_27000   AFIB   RBBB TWC          85    MALE
# 1      MUSE_20180112_073319_29000     SB        TWC          59  FEMALE
# 2      MUSE_20180111_165520_97000     SA       NONE          20  FEMALE
# 3      MUSE_20180113_121940_44000     SB       NONE          66    MALE
# 4      MUSE_20180112_122850_57000     AF  STDD STTC          73  FEMALE
# ...                           ...    ...        ...         ...     ...
# 10641  MUSE_20181222_204306_99000    SVT       NONE          80  FEMALE
# 10642  MUSE_20181222_204309_22000    SVT       NONE          81  FEMALE
# 10643  MUSE_20181222_204310_31000    SVT       NONE          39    MALE
# 10644  MUSE_20181222_204312_58000    SVT       NONE          76    MALE
# 10645  MUSE_20181222_204314_78000    SVT       NONE          75    MALE
#
#        VentricularRate  AtrialRate  QRSDuration  QTInterval  QTCorrected  \
# ...

# %%
df1['Rhythm'].value_counts()
# Out:
# SB       3889
# SR       1826
# AFIB     1780
# ST       1568
# SVT       587
# AF        445
# SA        399
# AT        121
# AVNRT      16
# AVRT        8
# SAAWR       7
# Name: Rhythm, dtype: int64

# %%
df1['Rhythm'] = df1['Rhythm'].replace(['AF'],'AFIB')
df1['Rhythm'] = df1['Rhythm'].replace(['SVT'],'GSVT')
df1['Rhythm'] = df1['Rhythm'].replace(['AT'],'GSVT')
df1['Rhythm'] = df1['Rhythm'].replace(['SAAWR'],'GSVT')
df1['Rhythm'] = df1['Rhythm'].replace(['ST'],'GSVT')
df1['Rhythm'] = df1['Rhythm'].replace(['AVNRT'],'GSVT')
df1['Rhythm'] = df1['Rhythm'].replace(['AVRT'],'GSVT')
df1['Rhythm'] = df1['Rhythm'].replace(['SI'],'SR')
df1['Rhythm'] = df1['Rhythm'].replace(['SA'],'SR')

# %%
df1['Rhythm'].value_counts()
# Out:
# SB      3889
# GSVT    2307
# AFIB    2225
# SR      2225
# Name: Rhythm, dtype: int64

# %%
df1.to_csv("F:/4 class Diagnostics.csv")
